# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# setting plot size
# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 9)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run ./feature_engineering.py
# %run ./utils.py

# %% [markdown]
# # 1. ALL DATA

# %% [markdown]
# ## 1.0. IMPORTING/CLEANING DATA

# %%
import time
start = time.time()
# i want the list of the files from there 
import os
tickers = os.listdir("/Users/edouardcuny/Desktop/quant/Carmela/data2/")
l = []
for ticker in tickers:
    if 'csv' in ticker:
        df = build_df(ticker)
        l.append(df)

df = pd.concat(l, axis=0)
# df.to_csv("/Users/edouardcuny/Desktop/stocks.csv")

# removing rows w/ infinite
df.replace([np.inf, -np.inf], np.nan,inplace=True)

# removing rows w/ NaN i.e. first rows and last rows based on window_size
df.dropna(inplace=True)

stop = time.time()
print
print 'temps de création du DataFrame : ' + str(round(stop - start))
# Out:
# AC - dropped NA : 4653 >> 4613
# ACA - dropped NA : 4144 >> 4120
# AI - dropped NA : 4653 >> 4616
# AIR - dropped NA : 4218 >> 4187
# ATO - dropped NA : 4653 >> 4614
# BN - dropped NA : 7513 >> 6585
# BNP - dropped NA : 6273 >> 5773
# CA - dropped NA : 4653 >> 4616
# CAP - dropped NA : 4653 >> 4608
# DG - dropped NA : 4653 >> 4613
# EI - dropped NA : 4653 >> 4600
# EN - dropped NA : 6998 >> 6625
# ENGI - dropped NA : 4653 >> 4447
# FP - dropped NA : 4653 >> 4613
# FR - dropped NA : 4652 >> 2231
# GLE - dropped NA : 4653 >> 4615
# KER - dropped NA : 4653 >> 4483
# LHN - dropped NA : 656 >> 656
# LR - dropped NA : 3019 >> 3016
# MC - dropped NA : 4653 >> 4609
# ML - dropped NA : 4653 >> 4615
# OR - dropped NA : 4653 >> 4610
# ORA - dropped NA : 4653 >> 4615
# SAN - dropped NA : 4653 >> 4607
# SGO - dropped NA : 4642 >> 3805
# SU - dropped NA : 4653 >> 4614
# SW - dropped NA : 22 >> 22
# UG - dropped NA : 4653 >> 4610
# VIE - dropped NA : 4510 >> 4471
# VIV - dropped NA : 4653 >> 4614
# ...

# %% [markdown]
# ## 1.1. ML

# %%
X_train,X_test,Y_train,Y_test = split_train_test(df,date="2012-12-31")

# un dataframe un peu spécial
# il est exactement comme X_train de façon à ce qu'on puisse lui affecter le ML sauf qu'il a en plus
# - l'adj close (de façon à calculer la valeur du portfolio)
# - son ticker 
df_portfolio = X_test.copy()
# Out:
# dropped extreme values : 126954 >> 126954
# dropped NA : 126954 >> 126954

# %%
# droping useless columns
to_drop = []
to_drop.append('rolling_mean')
to_drop.append('Adj Close')
to_drop.append('vol_rolling_mean')
to_drop.append('Ticker')

X_train.drop(to_drop,axis=1,inplace=True)
X_test.drop(to_drop,axis=1,inplace=True)

# %%
print X_train.shape
print X_test.shape
print Y_train.shape
print Y_test.shape
# Out:
# (91665, 45)
# (35289, 45)
# (91665,)
# (35289,)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=7)
clf.fit(X_train,Y_train)
Y_pred = pd.Series(clf.predict(X_test))
Y_pred.index = Y_test.index

# %%
print len(Y_test[Y_test!=0])
print len(Y_test)
print np.float64(len(Y_test[Y_test!=0]))/len(Y_test)
print
print len(Y_pred[Y_pred!=0])
print len(Y_pred)
print np.float64(len(Y_pred[Y_pred!=0]))/len(Y_pred)

from sklearn.metrics import accuracy_score, log_loss, roc_auc_score

print
print 'accuracy : ' + str(accuracy_score(Y_test,Y_pred))
# Out:
# 17298
# 35289
# 0.490181076256
#
# 14051
# 35289
# 0.39816940123
#
# accuracy : 0.431550908215

# %% [markdown]
# # PLAYGROUND

# %%
tickers = list(df_portfolio['Ticker'].value_counts().index)

# %% [markdown]
# # vérification visuelle

# %%
for ticker in tickers:
    df_stock = df_portfolio.loc[df_portfolio['Ticker']==ticker,'Adj Close']
    df_stock.plot(title=ticker)
    plt.show()

df_portfolio['Ticker'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-e1a638a5a42a> in <module>()
#       2     df_stock = df_portfolio.loc[df_portfolio['Ticker']==ticker,'Adj Close']
#       3     df_stock.plot(title=ticker)
# ----> 4     plt.show()
#
# /Users/edouardcuny/.pyenv/versions/2.7.10/envs/ml/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# /Users/edouardcuny/.pyenv/versions/2.7.10/envs/ml/lib/python2.7/site-packages/ipykernel/pylab/backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ...

# %%
# on dégage les colonnes :
# KER, ENG, SGO, SAN, FR, LHN
to_drop = ['KER', 'ENG', 'SGO', 'SAN', 'FR', 'LHN']
print df_portfolio.shape
df_portfolio = df_portfolio[~df_portfolio['Ticker'].isin(to_drop)]
print df_portfolio.shape
# Out:
# (30866, 49)
# (30866, 49)

# %%
dates.join(df_portfolio.loc[df_portfolio['Ticker']=='BN','Adj Close'])
pf = pd.DataFrame(df_portfolio.loc[df_portfolio['Ticker']=='BN','Adj Close']).join(df_portfolio.loc[df_portfolio['Ticker']=='GLE','Adj Close'],lsuffix='BN')
tickers.remove('BN')
tickers.remove('GLE')

# %%
pr_ticker = 'GLE'
for ticker in tickers : 
    pf = pf.join(df_portfolio.loc[df_portfolio['Ticker']==ticker,'Adj Close'],lsuffix=pr_ticker)
    pr_ticker = ticker

# %%
# PORTFOLIO EVOLUTION
allocation = pf.iloc[0,:]/pf.iloc[0,:].sum()

# %%
funds = 1000

def portfolio_evolution(allocation,funds,df):
    df_2 = df.apply(lambda x: x/x[0]) # normalisation
    df_2 = df_2*allocation
    df_2 = df_2*funds
    df_2['TOTAL']=df_2.sum(axis=1)
    return df_2

# %%
evo = portfolio_evolution(allocation,funds,pf)
evo.head(10)
# Out:
#             Adj CloseBN  Adj CloseGLE  Adj CloseUG  Adj CloseFP  Adj CloseLR  \
# Date
# 2013-01-02    49.593360     28.174057     4.945069    33.805671    32.973551
# 2013-01-03    49.074409     27.914499     5.082732    33.704202    33.212121
# 2013-01-04    48.956917     27.683253     5.556007    33.674602    33.597895
# 2013-01-07    48.555467     28.438336     5.868219    33.112227    33.267956
# 2013-01-08    48.687651     29.339719     5.591992    33.306728    33.090299
# 2013-01-09    48.575048     30.344925     5.680170    33.429355    33.069993
# 2013-01-10    48.878583     30.864044     5.532608    33.446269    32.846651
# 2013-01-11    48.565262     31.048093     5.488519    33.391299    32.587775
# 2013-01-14    48.193188     32.223191     5.761146    33.497004    32.689297
# 2013-01-15    48.795362     31.609691     5.936599    33.598481    32.323826
#
#             Adj CloseEI  Adj CloseCA  Adj CloseAI  Adj CloseSU  Adj CloseBNP  \
# Date
# ...

# %%
# on ajoute le CAC
cac = pd.read_csv('/Users/edouardcuny/Desktop/quant/Carmela/CAC40.csv',index_col='Date',dtype={'Adj Close': np.float64})
evo = evo.join(cac['Adj Close'], rsuffix = 'CAC40')
evo.iloc[:,-1]=evo.iloc[:,-1]/evo.iloc[0,-1]*1000
evo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-15aaf4d5f990> in <module>()
#       1 # on ajoute le CAC
# ----> 2 cac = pd.read_csv('/Users/edouardcuny/Desktop/quant/Carmela/CAC40.csv',index_col='Date',dtype=np.float64)
#       3 evo = evo.join(cac['Adj Close'], rsuffix = 'CAC40')
#       4 evo.iloc[:,-1]=evo.iloc[:,-1]/evo.iloc[0,-1]*1000
#       5 evo
#
# ...

# %%
evo['TOTAL'].plot()
evo['Adj CloseCAC40'].plot()
plt.show()
